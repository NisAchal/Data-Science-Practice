# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#Generate rand num from skewed normal distribution
x = np.random.standard_t(10, size=1000)
x[:15]
# Out:
# array([ 2.21611802, -2.25418514,  0.11173007, -0.11346443,  0.40413466,
#         0.52496139, -1.50550701,  0.9875593 ,  0.51919097,  0.65250327,
#         0.36641074,  0.72910182,  0.2126375 ,  0.66538497, -0.6150762 ])

# %%
plt.hist(x, color='teal')
# Out:
# (array([  1.,   2.,  13.,  61., 188., 334., 248., 111.,  32.,  10.]),
#  array([-4.93949101, -4.07879319, -3.21809538, -2.35739756, -1.49669975,
#         -0.63600193,  0.22469588,  1.08539369,  1.94609151,  2.80678932,
#          3.66748714]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Range

# %%
max_value = np.max(x)
min_value = np.min(x)

# %%
print(f"Max Value:{max_value}")
print(f"Min Value:{min_value}")
# Out:
# Max Value:3.667487137839342
# Min Value:-4.939491005531247

# %%
range = max_value - min_value
print(f"Range:{range}")
# Out:
# Range:8.60697814337059

# %% [markdown]
# ## Inter Quartile Range(IQR)

# %%
q1 = np.percentile(x, 25)
q3 = np.percentile(x, 75)

# %%
iqr = q3 - q1

# %%
print(f"IQR",iqr)
# Out:
# IQR 1.4138394928279336

# %% [markdown]
# ## Mean Absolute Deviation

# %%
mean = x.mean()

# %%
mad = np.mean(np.abs(x-mean))
print("MAD:",mad)
# Out:
# MAD: 0.8554273741796995

# %%
plt.hist(x, color = 'teal')
plt.axvline(x = mad, color = 'black')
plt.axvline(x = mean, color = 'blue')
